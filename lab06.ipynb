# %%
# from __future__ import print_function, division

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Part 1

# %%
# TODO define gaussian function here
def gaussian(x, amp, sigma):
    return amp*np.exp(-(x**2)/(2*sigma**2))

# %%
xdata = np.arange(-5, 5, .01)
y1 = gaussian(x,1,1)
ydata = gaussian(x,2,1)

# %%
plt.plot(x,y1)
plt.plot(x,y2)
plt.gcf().set_size_inches(14,10)
plt.show()

# %%
# TODO fit gaussians, with known parameters, here
#def logistic(x, amp, sigma):
  #  return amp*np.exp(-(x**2)/(2*sigma**2))

# %%
from scipy import integrate
from scipy import optimize
params, cov = optimize.curve_fit(gaussian, x, ydata)
plt.plot(ydata, gaussian(ydata, *params))
print(*params)
#dereference the parameters
x = np.arange(-5, 5, .01)
y = gaussian(x,2,1)
plt.plot(x,y)
plt.plot(xdata,ydata,":")


# TODO plot result
# Out:
# 2.0 1.0

# %%
# TODO: load data here
x_data, y_data = np.loadtxt('HDalpha_data', unpack=True)
# Out:
# array([13135.9, 13135.8, 13135.7, 13135.6, 13135.5, 13135.4, 13135.3,
#        13135.2, 13135.1, 13135. , 13134.9, 13134.8, 13134.7, 13134.6,
#        13134.5, 13134.4, 13134.3, 13134.2, 13134.1, 13134. , 13133.9,
#        13133.8, 13133.7, 13133.6, 13133.5, 13133.4, 13133.3, 13133.2,
#        13133.1, 13133. , 13132.9, 13132.8, 13132.7, 13132.6, 13132.5,
#        13132.4, 13132.3, 13132.2, 13132.1, 13132. , 13131.9, 13131.8,
#        13131.7, 13131.6, 13131.5, 13131.4, 13131.3, 13131.2, 13131.1,
#        13131. , 13130.9, 13130.8, 13130.7, 13130.6, 13130.5, 13130.4,
#        13130.3, 13130.2, 13130.1, 13130. , 13129.9, 13129.8, 13129.7,
#        13129.6, 13129.5, 13129.4, 13129.3, 13129.2, 13129.1, 13129. ,
#        13128.9, 13128.8, 13128.7, 13128.6, 13128.5, 13128.4, 13128.3,
#        13128.2, 13128.1, 13128. , 13127.9, 13127.8, 13127.7, 13127.6,
#        13127.5, 13127.4, 13127.3, 13127.2, 13127.1, 13127. , 13126.9,
#        13126.8, 13126.7, 13126.6, 13126.5, 13126.4, 13126.3, 13126.2,
#        13126.1, 13126. , 13125.9, 13125.8, 13125.7, 13125.6, 13125.5,
#        13125.4, 13125.3, 13125.2, 13125.1, 13125. , 13124.9, 13124.8,
#        13124.7, 13124.6, 13124.5, 13124.4, 13124.3, 13124.2, 13124.1,
#        13124. , 13123.9, 13123.8])

# %%
# TODO: plot it
plt.plot(x_data,y_data)
plt.show()

# %%
# TODO: plot data as emission signal
plt.plot(x_data,-y_data)
plt.show()

# %%
# TODO: fit a function to this data and plot it

# %% [markdown]
# # Part 2

# %%
# TODO: part 2

# %% [markdown]
# # Part 3

# %%
def flux_for_dipole(x_pos, y_pos, Q_vals, X, Y):
    """
    Returns the flux based on the information of the charges
    and the grid of the plot.
    Code modified from Physics 113, written by Blas Cabrera
    """
    flux = np.zeros((len(X), len(Y)))
    x_m = np.outer(np.ones((X.size)), X); 
    y_m = np.outer(Y, np.ones((Y.size))); 
    for n in range(len(Q_vals)):
        flux += 2*np.pi*Q_vals[n]*(1 - (x_pos[n]-x_m)/np.sqrt((y_pos[n]-y_m)**2+(x_pos[n]-x_m)**2))
    return flux

# %%
# TODO create arrays of information

# TODO get flux

# TODO plot contours of the flux
